# %%
import time #modulo de tiempo
import numpy as np #modulo de arreglos y matrices
from matplotlib import pyplot as plt  #librearia de graficos

# %%
#funcion que calcula   el fibonacci
#tomando como parametro al numero que se le aplica fib
def fib(x):
    a=0
    b=1
    c=0
    for i in range(x):
        c=a+b
        a=b
        b=c
    return c

# %%
#funcion calcula los valores de la funcion de fibonacci para todos los valores de n
#calcula el tiempo que toma cada valor de n para usar la funcion de fibonacci
def graf(n,tin):
    t=tin
    # n valores de iteracion 0 hasta n
    vx=[]
    #tiempos que tarda la funcion fib(n) para cada valor de n 
    vy=[]
    #valores de f(n) para valores de 0 hasta n
    vz=[]
    for i in range(n):
        a=fib(i)
        b=time.clock()-t
        vx.append(i)
        vy.append(b)
        vz.append(a)
        t=time.clock()
    return vx,vy,vz

# %%
n=10000
tiempo=time.clock()
print tiempo
x,y,z=graf(n,tiempo)
# Out:
# 430.7107335

# %%
plt.plot(x,y,'ko')
plt.legend(('tiempo de ejecucion fibonacci' ), loc = 'upper left')
plt.xlabel("numeros de fibonacci", fontsize = 20)
plt.ylabel("tiempo de ejecucion segundos", fontsize = 20)
plt.title("tiempo de ejecucion fibonacci", fontsize = 20)
# Out:
# Text(0.5,1,'tiempo de ejecucion fibonacci')

# %%
plt.plot(x,z[:100],'ro')
plt.legend(('tiempo de ejecucion fibonacci' ), loc = 'upper left')
plt.xlabel(("fib de n"), fontsize = 20)
plt.ylabel("tiempo de ejecucion segundos", fontsize = 20)
plt.title("valores de fib de n vs n", fontsize = 20)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-33-d5091ab2630e> in <module>()
# ----> 1 plt.plot(x,z[:100],'ro')
#       2 plt.legend(('tiempo de ejecucion fibonacci' ), loc = 'upper left')
#       3 plt.xlabel(("fib de n"), fontsize = 20)
#       4 plt.ylabel("tiempo de ejecucion segundos", fontsize = 20)
#       5 plt.title("valores de fib de n vs n", fontsize = 20)
#
# C:\Users\dhram\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# C:\Users\dhram\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\dhram\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# C:\Users\dhram\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# C:\Users\dhram\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# C:\Users\dhram\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (10000L,) and (100L,)
